# %% [markdown]
# <a href="https://colab.research.google.com/github/himanithakar1002/Feature-Extraction/blob/main/Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from PIL import Image
# %matplotlib inline

# %%
uploded=files.upload()
# Out:
#      <input type="file" id="files-3a1e6cad-aacb-49d6-9472-83c0a74dc8bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a1e6cad-aacb-49d6-9472-83c0a74dc8bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.jpg to dog (1).jpg

# %%
image1 = imread('dog.jpg')
imshow(image1);

# %%
image2 = imread('dog.jpg', as_gray=True)
imshow(image2);

# %%
print(image1.shape)
print(image2.shape)
# Out:
# (497, 968, 3)
# (497, 968)

# %%
print(image1.size)
print(image2.size)
# Out:
# 1443288
# 481096

# %%
pixel_feat1 = np.reshape(image2, (497 * 968))
pixel_feat1
# Out:
# array([0.19775882, 0.20168039, 0.20757412, ..., 0.46514549, 0.47827137,
#        0.55247569])

# %%
pixel_feat2 = np.reshape(image1, (497 * 968 * 3))
pixel_feat2
# Out:
# array([ 73,  48,   8, ..., 140, 150,  53], dtype=uint8)

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)

#Plotting the Image and the Histogram of gray values
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# Out:
# Text(0.5, 1.0, 'histogram of gray values')

# %%
import cv2
from google.colab.patches import cv2_imshow

img_rotate_90_clockwise = cv2.rotate(image1, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img_rotate_90_clockwise)
img_rotate_90_counterclockwise = cv2.rotate(image1, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(img_rotate_90_counterclockwise)
img_rotate_180 = cv2.rotate(image1, cv2.ROTATE_180)
cv2_imshow(img_rotate_180)
# Out:
# <PIL.Image.Image image mode=RGB size=497x968 at 0x7F459F6D55D0>
# <PIL.Image.Image image mode=RGB size=497x968 at 0x7F459F6A97D0>
# <PIL.Image.Image image mode=RGB size=968x497 at 0x7F459F6D5550>
